# %%
x=float(input("Enter the number:"))
x=float(input("choose the conversion between: \n1.meter. \n2.centimeter\n"))

if x==1:
    meter=float(input("enter the number:"))
    print("meter",meter*100)
elif x==2:
    centimeter=float(input("enter the number:"))
    print("centimeter",centimeter*1)
# Out:
# Enter the number: 62
# choose the conversion between:
# 1.meter.
# 2.centimeter
#  1
# enter the number: 211
# meter 21100.0
