# %%
age=int(input("enter your age:"))

if age >= 18:
     print("you can watch movie")
     print("show mw your id")

elif age <= 18 and age >= 15:
     print("you can watch movie")  

else:
     print("not allowed")

# 7. we can add as many ages we want in elif statement
