# %%
# ATM 
ATM=987654321
PIN=2512
Balance=5000
ATM=int(input("Enter your Card:"))
if ATM !=987654321:
   print("your card details are wrong,RE-ENTER")
   exit()        # exit() it can be written to stop the machine the machine wen it is not correct
else:
   print("your card details are correct")

Balance=print("your balance is:",Balance)
PIN=int(input("Enter your PIN:"))

if PIN != 2512:
    print("Your PIN is incorrect")
else:
    print("Your PIN is correct")
machine=int(input("Choose which language u would prefer:  \n1.Hindi: \n2.English:"))

if machine==Balance:
  print("your Balance:",Balance)
# Out:
# Enter your Card: 514513
# your card details are wrong,RE-ENTER
# your balance is: 5000
# Enter your PIN: 2512
# Your PIN is correct
# Choose which language u would prefer:
# 1.Hindi:
# 2.English: 1

# %%
# ATM 
ATM=987654321
PIN=2512
Balance=5000
ATM=int(input("Enter your Card:"))
if ATM !=987654321:
   print("your card details are wrong,RE-ENTER")
   exit()         # exit() it can be written to stop the machine the machine wen it is not correct
else:
   print("your card details are correct")

Balance=print("your balance is:",Balance)
PIN=int(input("Enter your PIN:"))

if PIN != 2512:
    print("Your PIN is incorrect")
else:
    print("Your PIN is correct")
machine=int(input("Choose which language u would prefer:  \n1.Hindi: \n2.English:"))

if machine==Balance:
  print("your Balance:",Balance)
# Out:
# Enter your Card: 987654321
# your card details are correct
# your balance is: 5000
# Enter your PIN: 2512
# Your PIN is correct
# Choose which language u would prefer:
# 1.Hindi:
# 2.English: 2
